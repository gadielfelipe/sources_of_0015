# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Usuario\\OneDrive - Global Green Growth Institute\\Documentos\\2025\\Stress Test\\Data\\Scripts Python'

# %%
os.chdir('C://Users//Usuario//OneDrive - Global Green Growth Institute//Documentos//2025//Stress Test//Data//Escenarios Cambio Climatico IDEAM IV comunicacion//Mensuales//')

# %%
os.listdir()
# Out:
# ['DatosDiarios_Precipitacion_SSP126_2021-2040.txt',
#  'DatosMensuales_HumedadRelativa_SSP126_2021-2100.txt',
#  'DatosMensuales_HumedadRelativa_SSP245_2021-2100.txt',
#  'DatosMensuales_HumedadRelativa_SSP370_2021-2100.txt',
#  'DatosMensuales_HumedadRelativa_SSP585_2021-2100.txt',
#  'DatosMensuales_Precipitacion_SSP126_2021-2100.txt',
#  'DatosMensuales_Precipitacion_SSP245_2021-2100.txt',
#  'DatosMensuales_Precipitacion_SSP370_2021-2100.txt',
#  'DatosMensuales_Precipitacion_SSP585_2021-2100.txt',
#  'DatosMensuales_Radiacion_SSP126_2021-2100.txt',
#  'DatosMensuales_Radiacion_SSP245_2021-2100.txt',
#  'DatosMensuales_Radiacion_SSP370_2021-2100.txt',
#  'DatosMensuales_Radiacion_SSP585_2021-2100.txt',
#  'DatosMensuales_TemperaturaMaxima_SSP126_2021-2100.txt',
#  'DatosMensuales_TemperaturaMaxima_SSP245_2021-2100.txt',
#  'DatosMensuales_TemperaturaMaxima_SSP370_2021-2100.txt',
#  'DatosMensuales_TemperaturaMaxima_SSP585_2021-2100.txt',
#  'DatosMensuales_TemperaturaMedia_SSP126_2021-2100.txt',
#  'DatosMensuales_TemperaturaMedia_SSP245_2021-2100.txt',
#  'DatosMensuales_TemperaturaMedia_SSP370_2021-2100.txt',
#  'DatosMensuales_TemperaturaMedia_SSP585_2021-2100.txt',
#  'DatosMensuales_TemperaturaMinima_SSP126_2021-2100.txt',
#  'DatosMensuales_TemperaturaMinima_SSP245_2021-2100.txt',
#  'DatosMensuales_TemperaturaMinima_SSP370_2021-2100.txt',
#  'DatosMensuales_TemperaturaMinima_SSP585_CuboDatos_2021-2100.txt',
#  'DatosMensuales_VelocidadDelViento_SSP126_2021-2100.txt',
#  'DatosMensuales_VelocidadDelViento_SSP245_2021-2100.txt',
#  'DatosMensuales_VelocidadDelViento_SSP370_2021-2100.txt',
#  'DatosMensuales_VelocidadDelViento_SSP585_2021-2100.txt',
#  'davipola_dane.xlsx',
#  'uribia_proy.xlsx']

# %%
data_ = pd.read_csv(
    'DatosMensuales_Precipitacion_SSP370_2021-2100.txt',
    sep='\t',
    engine='python',
    encoding='Latin-1'
)

# %%
data_.head()
# Out:
#    1  -71.7  12.4  LA GUAJIRA  URIBIA  Caribe  Caribe - Guajira  \
# 0  2  -71.6  12.4  LA GUAJIRA  URIBIA  Caribe  Caribe - Guajira
# 1  3  -71.5  12.4  LA GUAJIRA  URIBIA  Caribe  Caribe - Guajira
# 2  4  -71.7  12.3  LA GUAJIRA  URIBIA  Caribe  Caribe - Guajira
# 3  5  -71.6  12.3  LA GUAJIRA  URIBIA  Caribe  Caribe - Guajira
# 4  6  -71.5  12.3  LA GUAJIRA  URIBIA  Caribe  Caribe - Guajira
#
#   RÃ­o Carraipia - Paraguachon, Directos al Golfo Maracaibo; Directos Caribe - Ay.Sharimahana Alta Guajira  \
# 0  RÃ­o Carraipia - Paraguachon, Directos al Golf...
# 1  RÃ­o Carraipia - Paraguachon, Directos al Golf...
# 2      Directos Caribe - Ay.Sharimahana Alta Guajira
# 3  RÃ­o Carraipia - Paraguachon, Directos al Golf...
# 4  RÃ­o Carraipia - Paraguachon, Directos al Golf...
#
#    2  Caribe - Cesar  ...  0.1.44  4.1.2  1.9.9  2.3.3  8.6.3  17.2  39.9  \
# 0  2  Caribe - Cesar  ...     0.4    5.6    2.6    3.3    9.1  20.4  46.5
# 1  2  Caribe - Cesar  ...     0.4    6.3    2.9    3.3    9.3  22.0  49.9
# 2  2  Caribe - Cesar  ...     0.1    3.8    1.6    2.3    7.3  15.4  35.3
# 3  2  Caribe - Cesar  ...     0.4    6.6    3.0    3.8   11.1  25.6  58.2
# 4  2  Caribe - Cesar  ...     0.0    5.4    1.7    3.7   13.1  26.7  68.7
#
#    51.5.2  48.3  4.12
# 0    57.4  55.3   4.5
# 1    61.1  58.1   5.3
# 2    44.5  41.6   3.7
# 3    71.9  69.4   5.7
# 4    84.3  85.4   6.2
#
# [5 rows x 970 columns]
